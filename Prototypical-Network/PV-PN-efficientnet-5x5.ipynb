# %%
# !pip install easyfsl
# !pip install scikit-learn
# !pip install efficientnet_pytorch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: easyfsl in /home/ghos1y/.local/lib/python3.10/site-packages (1.5.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from easyfsl) (3.8.1)
# Requirement already satisfied: pandas>=1.5.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from easyfsl) (2.1.2)
# Requirement already satisfied: torch>=1.5.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from easyfsl) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.7.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from easyfsl) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.1.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from easyfsl) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->easyfsl) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (0.12.1)
# Requirement already satisfied: numpy<2,>=1.21 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (1.24.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (23.1)
# Requirement already satisfied: pillow>=8 in /home/ghos1y/.local/lib/python3.10/site-packages (from matplotlib>=3.0.0->easyfsl) (9.3.0)
# Requirement already satisfied: tzdata>=2022.1 in /home/ghos1y/.local/lib/python3.10/site-packages (from pandas>=1.5.0->easyfsl) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ghos1y/.local/lib/python3.10/site-packages (from pandas>=1.5.0->easyfsl) (2023.3.post1)
# Requirement already satisfied: networkx in /home/ghos1y/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (3.0)
# Requirement already satisfied: typing-extensions in /home/ghos1y/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (4.4.0)
# Requirement already satisfied: jinja2 in /home/ghos1y/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (3.1.2)
# Requirement already satisfied: filelock in /home/ghos1y/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (3.9.0)
# Requirement already satisfied: triton==2.0.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (2.0.0)
# Requirement already satisfied: sympy in /home/ghos1y/.local/lib/python3.10/site-packages (from torch>=1.5.0->easyfsl) (1.12)
# Requirement already satisfied: lit in /home/ghos1y/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.5.0->easyfsl) (15.0.7)
# Requirement already satisfied: cmake in /home/ghos1y/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.5.0->easyfsl) (3.25.0)
# Requirement already satisfied: requests in /home/ghos1y/.local/lib/python3.10/site-packages (from torchvision>=0.7.0->easyfsl) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->easyfsl) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from jinja2->torch>=1.5.0->easyfsl) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ghos1y/.local/lib/python3.10/site-packages (from requests->torchvision>=0.7.0->easyfsl) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ghos1y/.local/lib/python3.10/site-packages (from requests->torchvision>=0.7.0->easyfsl) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/ghos1y/.local/lib/python3.10/site-packages (from requests->torchvision>=0.7.0->easyfsl) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ghos1y/.local/lib/python3.10/site-packages (from requests->torchvision>=0.7.0->easyfsl) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /home/ghos1y/.local/lib/python3.10/site-packages (from sympy->torch>=1.5.0->easyfsl) (1.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/ghos1y/.local/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/ghos1y/.local/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/ghos1y/.local/lib/python3.10/site-packages (from scikit-learn) (1.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: efficientnet_pytorch in /home/ghos1y/.local/lib/python3.10/site-packages (0.7.1)
# Requirement already satisfied: torch in /home/ghos1y/.local/lib/python3.10/site-packages (from efficientnet_pytorch) (2.0.1+cu118)
# Requirement already satisfied: jinja2 in /home/ghos1y/.local/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: sympy in /home/ghos1y/.local/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: triton==2.0.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (2.0.0)
# Requirement already satisfied: filelock in /home/ghos1y/.local/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.9.0)
# Requirement already satisfied: typing-extensions in /home/ghos1y/.local/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (4.4.0)
# Requirement already satisfied: networkx in /home/ghos1y/.local/lib/python3.10/site-packages (from torch->efficientnet_pytorch) (3.0)
# Requirement already satisfied: lit in /home/ghos1y/.local/lib/python3.10/site-packages (from triton==2.0.0->torch->efficientnet_pytorch) (15.0.7)
# Requirement already satisfied: cmake in /home/ghos1y/.local/lib/python3.10/site-packages (from triton==2.0.0->torch->efficientnet_pytorch) (3.25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ghos1y/.local/lib/python3.10/site-packages (from jinja2->torch->efficientnet_pytorch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ghos1y/.local/lib/python3.10/site-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)

# %%
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
import numpy as np

from torchvision import transforms
from efficientnet_pytorch import EfficientNet
from torchvision.datasets import VisionDataset
from torchvision.datasets.utils import list_dir, list_files

from tqdm import tqdm
from PIL import Image
from os.path import join
from typing import Any, Callable, List, Optional, Tuple

from easyfsl.samplers import TaskSampler
from easyfsl.utils import plot_images, sliding_average

from sklearn.metrics import auc, roc_curve, confusion_matrix, classification_report

# %% [markdown]
# # **<span style="color:#0DA7FF">Important Variables</span>**

# %%
colorMode = "RGB"  # Color = 'RGB' || Grayscale = 'L'
image_size = 64  # Image size in pixels

N_WAY = 5  # Number of classes in a task
N_SHOT = 5  # Number of images per class in the support set
N_QUERY = N_SHOT  # Number of images per class in the query set

N_TRAINING_EPISODES = 10000     # Number of tasks to sample during training
N_EVALUATION_TASKS = 1000       # Number of tasks to sample for meta-evaluation

Dataset_Root_Folder = "../data"
Dataset_Name = "PlantVillage"

# %% [markdown]
# ### <span style="color:#32FF0D">Custom Dataset Class</span>

# %%
class Dataset(VisionDataset):

    folder = Dataset_Name

    def __init__(
        self,
        root: str,
        background: bool = True,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
    ) -> None:
        super().__init__(join(root, self.folder), transform=transform, target_transform=target_transform)
        self.background = background

        self.target_folder = join(self.root, self._get_target_folder())
        self._plant = list_dir(self.target_folder)
        self._leafs: List[str] = sum(
            ([join(a, c) for c in list_dir(join(self.target_folder, a))] for a in self._plant), []
        )
        self._leaf_images = [
            [(image, idx) for image in list_files(join(self.target_folder, leaf), ".JPG")]
            for idx, leaf in enumerate(self._leafs)
        ]
        self._flat_leaf_images: List[Tuple[str, int]] = sum(self._leaf_images, [])

    def __len__(self) -> int:
        return len(self._flat_leaf_images)

    def __getitem__(self, index: int) -> Tuple[Any, Any]:
        image_name, plant_leaf_class = self._flat_leaf_images[index]
        image_path = join(self.target_folder, self._leafs[plant_leaf_class], image_name)
        image = Image.open(image_path, mode="r").convert(colorMode)

        if self.transform:
            image = self.transform(image)

        if self.target_transform:
            plant_leaf_class = self.target_transform(plant_leaf_class)

        return image, plant_leaf_class

    def _get_target_folder(self) -> str:
        return "images_background" if self.background else "images_evaluation"

# %%
train_set = Dataset(
    root=Dataset_Root_Folder,
    background=True,
    transform=transforms.Compose(
        [
            transforms.RandomResizedCrop(image_size),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
        ]
    ),
)
test_set = Dataset(
    root=Dataset_Root_Folder,
    background=False,
    transform=transforms.Compose(
        [
            transforms.Resize([int(image_size * 1.15), int(image_size * 1.15)]),
            transforms.ToTensor(),
        ]
    ),
)

# %% [markdown]
# ### <span style="color:#00F7FF">Prototypical Network Class with EfficientNet CNN</span>

# %%
class PrototypicalNetworks(nn.Module):
    def __init__(self, backbone: nn.Module):
        super(PrototypicalNetworks, self).__init__()
        self.backbone = backbone

    def forward(
        self,
        support_images: torch.Tensor,
        support_labels: torch.Tensor,
        query_images: torch.Tensor,
    ) -> torch.Tensor:

        z_support = self.backbone.forward(support_images)
        z_query = self.backbone.forward(query_images)

        n_way = len(torch.unique(support_labels))
        z_proto = torch.cat(
            [
                z_support[torch.nonzero(support_labels == label)].mean(0)
                for label in range(n_way)
            ]
        )
        
        dists = torch.cdist(z_query, z_proto)
        scores = -dists
        return scores

efficientnet_model = EfficientNet.from_pretrained('efficientnet-b0')
efficientnet_model._fc = nn.Flatten()

model = PrototypicalNetworks(efficientnet_model).cuda()
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
test_set.get_labels = lambda: [instance[1] for instance in test_set._flat_leaf_images]
test_sampler = TaskSampler(
    test_set, n_way=N_WAY, n_shot=N_SHOT, n_query=N_QUERY, n_tasks=N_EVALUATION_TASKS
)

test_loader = DataLoader(
    test_set,
    batch_sampler=test_sampler,
    num_workers=12,
    pin_memory=True,
    collate_fn=test_sampler.episodic_collate_fn,
)

(
    example_support_images,
    example_support_labels,
    example_query_images,
    example_query_labels,
    example_class_ids,
) = next(iter(test_loader))

plot_images(example_support_images, "support images", images_per_row=N_SHOT)
plot_images(example_query_images, "query images", images_per_row=N_QUERY)

# %%
def evaluate_on_one_task(
    support_images: torch.Tensor,
    support_labels: torch.Tensor,
    query_images: torch.Tensor,
    query_labels: torch.Tensor,
) -> [int, int]:
    """
    Returns the number of correct predictions of query labels, and the total number of predictions.
    """
    return (
        torch.max(
            model(support_images.cuda(), support_labels.cuda(), query_images.cuda())
            .detach()
            .data,
            1,
        )[1]
        == query_labels.cuda()
    ).sum().item(), len(query_labels)
    
def evaluate(data_loader: DataLoader):
    total_predictions = 0
    correct_predictions = 0

    model.eval()
    with torch.no_grad():
        for episode_index, (
            support_images,
            support_labels,
            query_images,
            query_labels,
            class_ids,
        ) in tqdm(enumerate(data_loader), total=len(data_loader)):

            correct, total = evaluate_on_one_task(
                support_images, support_labels, query_images, query_labels
            )

            total_predictions += total
            correct_predictions += correct

    print(
        f"Model tested on {len(data_loader)} tasks. Accuracy: {(100 * correct_predictions/total_predictions):.2f}%"
    )

# %%
train_set.get_labels = lambda: [instance[1] for instance in train_set._flat_leaf_images]
train_sampler = TaskSampler(
    train_set, n_way=N_WAY, n_shot=N_SHOT, n_query=N_QUERY, n_tasks=N_TRAINING_EPISODES
)
train_loader = DataLoader(
    train_set,
    batch_sampler=train_sampler,
    num_workers=12,
    pin_memory=True,
    collate_fn=train_sampler.episodic_collate_fn,
)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def fit(
    support_images: torch.Tensor,
    support_labels: torch.Tensor,
    query_images: torch.Tensor,
    query_labels: torch.Tensor,
) -> float:
    optimizer.zero_grad()
    classification_scores = model(
        support_images.cuda(), support_labels.cuda(), query_images.cuda()
    )

    loss = criterion(classification_scores, query_labels.cuda())
    loss.backward()
    optimizer.step()

    return loss.item()

# %% [markdown]
# ### <span style="color:#00F7FF">Train Few Shot Model</span>

# %%
log_update_frequency = 10

all_loss = []
model.train()
with tqdm(enumerate(train_loader), total=len(train_loader)) as tqdm_train:
    for episode_index, (
        support_images,
        support_labels,
        query_images,
        query_labels,
        _,
    ) in tqdm_train:
        loss_value = fit(support_images, support_labels, query_images, query_labels)
        all_loss.append(loss_value)

        if episode_index % log_update_frequency == 0:
            tqdm_train.set_postfix(loss=sliding_average(all_loss, log_update_frequency))

# %% [markdown]
# ### Save Trained Model

# %%
import time
PATH = "../model-saves/EfficientNet/"+str(N_WAY)+"-way "+str(N_SHOT)+"-shot plant leaf classification "+time.strftime("%Y-%m-%d-%H%M%S")
torch.save(model, PATH)

# %% [markdown]
# ### Load Model

# %%
# model = torch.load("../model-saves/EfficientNet/5-way 5-shot plant leaf classification 2023-11-14-184846")

# %% [markdown]
# ### Calculate Accuracy (in %)

# %%
evaluate(test_loader)
# Out:
# 100%|██████████| 1000/1000 [00:26<00:00, 37.07it/s]
# Model tested on 1000 tasks. Accuracy: 77.91%

# %% [markdown]
# ### Calculate Top-K Accuracy (in %)

# %%
def top_k_accuracy(query_labels, predicted_scores, k=1):
    num_classes = predicted_scores.size(1)  # Get the number of classes

    if k > num_classes:
        k = num_classes  # Set k to the number of classes if it exceeds

    # Sort predicted scores in descending order and get the indices of the top-k predictions
    _, topk_indices = torch.topk(predicted_scores, k, dim=1, largest=True, sorted=True)
    
    correct_predictions = 0
    total_predictions = query_labels.size(0)
    
    for i in range(total_predictions):
        if query_labels[i] in topk_indices[i]:
            correct_predictions += 1

    accuracy = correct_predictions / total_predictions
    return accuracy

def evaluate_with_topk(data_loader, topk=1):
    total_predictions = 0
    correct_predictions = 0

    model.eval()
    with torch.no_grad():
        for episode_index, (
            support_images,
            support_labels,
            query_images,
            query_labels,
            class_ids,
        ) in tqdm(enumerate(data_loader), total=len(data_loader)):

            classification_scores = model(
                support_images.cuda(), support_labels.cuda(), query_images.cuda()
            )

            _, predicted_labels = torch.max(classification_scores.data, 1)

            correct, total = evaluate_on_one_task(
                support_images, support_labels, query_images, query_labels
            )

            total_predictions += total
            correct_predictions += correct

    accuracy = correct_predictions / total_predictions
    topk_accuracy = top_k_accuracy(query_labels, classification_scores, topk)

    # Calculate top-3 accuracy
    top3_accuracy = top_k_accuracy(query_labels, classification_scores, 3)
    
    return accuracy, topk_accuracy, top3_accuracy

# Evaluate the model with top-1, top-3, and top-5 accuracy
accuracy, top5_accuracy, top3_accuracy = evaluate_with_topk(test_loader, topk=5)
print(f"Top-1 Accuracy: {accuracy * 100:.2f}%")
print(f"Top-3 Accuracy: {top3_accuracy * 100:.2f}%")
print(f"Top-5 Accuracy: {top5_accuracy * 100:.2f}%")
# Out:
# 100%|██████████| 1000/1000 [00:48<00:00, 20.45it/s]
# Top-1 Accuracy: 77.66%
# Top-3 Accuracy: 96.00%
# Top-5 Accuracy: 100.00%

# %% [markdown]
# ### Model Confusion Matrix & Classification Report

# %%
def create_confusion_matrix(data_loader):
    true_labels = []
    predicted_labels = []

    model.eval()
    with torch.no_grad():
        for episode_index, (
            support_images,
            support_labels,
            query_images,
            query_labels,
            _,
        ) in tqdm(enumerate(data_loader), total=len(data_loader)):

            classification_scores = model(
                support_images.cuda(), support_labels.cuda(), query_images.cuda()
            )

            _, predicted = torch.max(classification_scores.data, 1)

            true_labels.extend(query_labels.cpu().numpy())
            predicted_labels.extend(predicted.cpu().numpy())

    cm = confusion_matrix(true_labels, predicted_labels)
    report = classification_report(true_labels, predicted_labels)

    return cm, report

confusion_matrix_result, classification_report_result = create_confusion_matrix(test_loader)
print("Confusion Matrix:")
print(confusion_matrix_result)

print("Classification Report:")
print(classification_report_result)
# Out:
# 100%|██████████| 1000/1000 [00:28<00:00, 35.36it/s]
# Confusion Matrix:
# [[4373  129  148  211  139]
#  [ 150 4045  282  289  234]
#  [ 160  308 3779  423  330]
#  [ 168  359  358 3704  411]
#  [ 101  286  384  570 3659]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      5000
#            1       0.79      0.81      0.80      5000
#            2       0.76      0.76      0.76      5000
#            3       0.71      0.74      0.73      5000
#            4       0.77      0.73      0.75      5000
#
#     accuracy                           0.78     25000
#    macro avg       0.78      0.78      0.78     25000
# weighted avg       0.78      0.78      0.78     25000

# %% [markdown]
# ### Calculate Model AUC

# %%
def create_confusion_matrix(data_loader, model):
    true_labels = []
    predicted_probs = []

    model.eval()
    with torch.no_grad():
        for episode_index, (
            support_images,
            support_labels,
            query_images,
            query_labels,
            _,
        ) in tqdm(enumerate(data_loader), total=len(data_loader)):

            classification_scores = model(
                support_images.cuda(), support_labels.cuda(), query_images.cuda()
            )

            # Extract probability scores
            probabilities = torch.nn.functional.softmax(classification_scores, dim=1)
            predicted_probs.extend(probabilities.cpu().numpy())

            true_labels.extend(query_labels.cpu().numpy())

    # Convert true labels to one-hot encoding
    true_labels_one_hot = np.eye(len(np.unique(true_labels)))[true_labels]

    # Calculate micro-average ROC AUC
    fpr, tpr, _ = roc_curve(true_labels_one_hot.ravel(), np.array(predicted_probs).ravel())
    roc_auc = auc(fpr, tpr)

    return roc_auc

auc_result = create_confusion_matrix(test_loader, model)
print("Micro-average AUC-ROC:", auc_result)
# Out:
# 100%|██████████| 1000/1000 [00:27<00:00, 36.18it/s]
# Micro-average AUC-ROC: 0.9549300876
